# %% [markdown]
# # Additional Neural Network Concepts

# %% [markdown]
# ## 1. Advanced Optimization
#
# An approach that is more efficient than gradient descent.
#
# ### 1.1 Adam algorithm (Adaptive Moment Estimation)
#
# Notice how **$a _ j$** (learning rate) adapts:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The learning rate $a_j$ increases or decreaces based on oscillation:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. Additional Layer Types
#
# ### 2.1 Convulutional Layer
#
# Each neuron only looks at part of the previous layer's outputs.
#
# ![image.png](attachment:image.png)
#
# #### Advantages:
#
# - Fater computation.
# - Needs less training data (less prone to overfitting)
