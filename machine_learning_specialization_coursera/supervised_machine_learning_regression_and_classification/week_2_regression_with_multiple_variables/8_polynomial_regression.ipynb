# %% [markdown]
# # Polynomial Regression
#
# This will be covered in the second course. This is an example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SciKit Library
#
# Comonly used: https://scikit-learn.org/stable/
#
# Scikit polynomial regression: https://scikit-learn.org/stable/modules/linear_model.html#polynomial-regression-extending-linear-models-with-basis-functions
