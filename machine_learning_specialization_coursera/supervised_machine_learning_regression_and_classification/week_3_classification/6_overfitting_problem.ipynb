# %% [markdown]
# # Overfitting problems

# %% [markdown]
# ## 1. What is overfitting

# %% [markdown]
# The chart on the right shows an example of "overfitting" data. The cost or loss may be closer to 0, but the predictions will probably still be wrong. The example on the right has a high "variance".
#
# ![image.png](attachment:image.png)
#
# The same can be true for classification models:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <br>
#
# ## 2. Addressing overfitting

# %% [markdown]
# ### 2.1 Collect more training data
#
# Variance can be reduced by providing more training examples.

# %% [markdown]
# ### 2.2 Use fewer features
#
# When data is limited, too many features may lead to overfitting.
#
# This however leads to loss of data. In course 2, an algorithm is introduced which helps with filtering out features.

# %% [markdown]
# ### 2.3 Regularization
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <br><br>
#
# # Overfitting lab

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import Output
from lib.plt_overfit import overfit_example, output
plt.style.use('./deeplearning.mplstyle')

# %%
plt.close("all")
display(output)
ofit = overfit_example(False)
# Out:
# Output()
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
