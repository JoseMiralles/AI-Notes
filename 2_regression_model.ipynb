# %% [markdown]
# # Regression Model
#
# Can have multiple inputs, and can have infinite output values.
#
# ## Linear Regression Model
#
# A model that generates a linear plot given a collection of plots. Outputs are then predicted based on this linear plot.
#
# ![image.png](attachment:16b109bf-24de-4805-b6b7-f6c488860592.png)
#
# ## Index (i) notation
#
# X ^ (i) = x value at row i.
#
# ![image.png](attachment:f7985569-5150-4fee-996a-3b441a84acda.png)

# %% [markdown]
# ## Notation
#
# ![image.png](attachment:c1e59c10-4f9d-4225-89cd-33262ad3decb.png)

# %% [markdown]
# ## Tools
# In this lab you will make use of:
# - NumPy, a popular library for scientific computing
# - Matplotlib, a popular library for plotting data

# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('./deeplearning.mplstyle')

# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# ### Number of training examples `m`
# `m` will be used to denote the number of training examples. Numpy arrays have a `.shape` parameter. `x_train.shape` returns a python tuple with an entry for each dimension. `x_train.shape[0]` is the length of the array and number of examples.

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")

# len() works as well
print(f"Len of training examples is: {len(x_train)}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2
# Len of training examples is: 2

# %% [markdown]
# ### Training example `x_i, y_i`
#
# (x$^{(i)}$, y$^{(i)}$) is used to denote the $i^{th}$ training example. Since Python is zero indexed, (x$^{(0)}$, y$^{(0)}$) is (1.0, 300.0) and (x$^{(1)}$, y$^{(1)}$) is (2.0, 500.0).

# %%
i = 0

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %% [markdown]
# # Ploting Data

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %% [markdown]
# # Linear Regression Model Function
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      f_wb (ndarray (m,)): model prediction
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb


w = 200
b = 100
print(f"weight: {w}")
print(f"bias: {b}")

tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Model Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()
# Out:
# weight: 200
# bias: 100

# %% [markdown]
# # Making a prediction

# %%
w = 200                         
b = 100    
x_i = 1.2
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f},000")
# Out:
# $340,000
